# %%
import sys
sys.path.append("..")

import numpy as np
import pymde
import matplotlib.pyplot as plt

import Graph
import Visualization
import DistMatrix
import Skeletonize
import MNIST

from importlib import reload

# %%
reload(MNIST)
train_x, train_Y = MNIST.load_pymde_mnist()
# Out:
# Aug 11 01:57:24 PM: Loading cached dataset.

# %%
mde = pymde.preserve_neighbors(train_x, embedding_dim=3, verbose=True)
embedding = mde.embed(verbose=True)
# Out:
# Aug 11 02:05:42 PM: Computing 15-nearest neighbors, with max_distance=None
# Wed Aug 11 14:05:42 2021 Building RP forest with 21 trees
# Wed Aug 11 14:05:44 2021 NN descent for 16 iterations
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	 4  /  16
# 	Stopping threshold met -- exiting after 4 iterations
# Aug 11 02:05:46 PM: Computing quadratic initialization.
# Aug 11 02:05:49 PM: Fitting a centered embedding into R^3, for a graph with 70000 items and 1552495 edges.
# Aug 11 02:05:49 PM: `embed` method parameters: eps=1.0e-05, max_iter=300, memory_size=10
# Aug 11 02:05:50 PM: iteration 000 | distortion 0.214286 | residual norm 0.00205482 | step length 166.774 | percent change 0.0747814
# Aug 11 02:05:54 PM: iteration 030 | distortion 0.122906 | residual norm 0.000190911 | step length 1 | percent change 1.16715
# Aug 11 02:05:58 PM: iteration 060 | distortion 0.119632 | residual norm 7.12972e-05 | step length 1 | percent change 0.137025
# ...

# %%
pymde.plot(embedding, color_by=train_Y)
# Out:
# f:\Git\Bachelor2.0\venv\lib\site-packages\pymde\experiment_utils.py:162: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# f:\Git\Bachelor2.0\venv\lib\site-packages\pymde\experiment_utils.py:199: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "g+" (-> marker='+'). The keyword argument will take precedence.
#   ax.plot(
# f:\Git\Bachelor2.0\venv\lib\site-packages\pymde\experiment_utils.py:199: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g+" (-> color='g'). The keyword argument will take precedence.
#   ax.plot(
# ...
