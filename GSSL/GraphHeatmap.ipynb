# %%
import numpy as np
import Graph
import Visualization as V
import importlib
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
importlib.reload(Graph)
importlib.reload(V)
# Out:
# <module 'Visualization' from 'f:\\Git\\Bachelor2.1\\GSSL\\Visualization.py'>

# %%
colors = ["#ff0000","#ff8700","#ffd300","#deff0a","#a1ff0a","#0aff99","#0aefff","#147df5","#580aff","#be0aff"]

# %%
g, l = Graph.load_graph_and_labels(10000, 30)
heat = V.g_neighbormap(g, l, show=False)

# %%
nids = [x for x in range(10)]
es = [(x, y) for x in range(10) for y in range(10)]

# %%
G = nx.DiGraph()

# %%
G.add_nodes_from(nids)
G.add_edges_from(es)
pos = nx.circular_layout(G)
node_sizes = np.diag()
plt.subplots(1, 1, figsize=(10, 10))

G.add_edge(0, 0)

nodes = nx.draw_networkx_nodes(G, pos, node_color=colors, node_size=500)
nx.draw_networkx_labels(G, pos, font_color="b", font_weight="bold")
edges = nx.draw_networkx_edges(
    G,
    pos,
    node_size=1000,
    arrowstyle="->",
    arrowsize=10,
    connectionstyle=f"arc3, rad=.09"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2550376bc47e> in <module>
#       2 G.add_edges_from(es)
#       3 pos = nx.circular_layout(G)
# ----> 4 node_sizes = np.diag()
#       5 plt.subplots(1, 1, figsize=(10, 10))
#       6
#
# <__array_function__ internals> in diag(*args, **kwargs)
#
# TypeError: _diag_dispatcher() missing 1 required positional argument: 'v'

# %%
import itertools
size = 5
block_size = 1
window_idxs = [(i, j) for i, j in
               itertools.product(range(0, size, block_size),
                                 range(0, size, block_size))]

print(window_idxs)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4), (3, 0), (3, 1), (3, 2), (3, 3), (3, 4), (4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]
